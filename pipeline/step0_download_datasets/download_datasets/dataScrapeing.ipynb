# %%
# !pip install pypdf2
# !pip install requests
# !pip install pycryptodom
# Out:
# DEPRECATION: Loading egg at /home/ubuntu/miniconda3/envs/.venv/lib/python3.11/site-packages/megatron_core-0.2.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting pypdf2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 20.1 MB/s eta 0:00:00
# Installing collected packages: pypdf2
# Successfully installed pypdf2-3.0.1
# DEPRECATION: Loading egg at /home/ubuntu/miniconda3/envs/.venv/lib/python3.11/site-packages/megatron_core-0.2.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: requests in /home/ubuntu/miniconda3/envs/.venv/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/miniconda3/envs/.venv/lib/python3.11/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ubuntu/miniconda3/envs/.venv/lib/python3.11/site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ubuntu/miniconda3/envs/.venv/lib/python3.11/site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/miniconda3/envs/.venv/lib/python3.11/site-packages (from requests) (2024.2.2)
# DEPRECATION: Loading egg at /home/ubuntu/miniconda3/envs/.venv/lib/python3.11/site-packages/megatron_core-0.2.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ERROR: Could not find a version that satisfies the requirement pycryptodom (from versions: none)
# ERROR: No matching distribution found for pycryptodom

# %%
# !pip install beautifulsoup4
# !pip install joblib
# Out:
# DEPRECATION: Loading egg at /home/ubuntu/miniconda3/envs/.venv/lib/python3.11/site-packages/megatron_core-0.2.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 12.0 MB/s eta 0:00:00
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.12.3 soupsieve-2.5
# DEPRECATION: Loading egg at /home/ubuntu/miniconda3/envs/.venv/lib/python3.11/site-packages/megatron_core-0.2.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: joblib in /home/ubuntu/miniconda3/envs/.venv/lib/python3.11/site-packages (1.3.2)

# %%
import requests
import os
from bs4 import BeautifulSoup
from joblib import Parallel, delayed

# クロールするウェブサイトのURL
urls = ["https://data.e-gov.go.jp/data/dataset/?q=報告書&res_format=PDF&res_license_id=cc-by&sort=score+desc%2C+metadata_modified+desc-20",
        "https://data.e-gov.go.jp/data/dataset/?q=報告書&res_format=PDF&res_license_id=gjstu&sort=score+desc%2C+metadata_modified+desc-20",
        "https://data.e-gov.go.jp/data/dataset/?q=報告書&res_format=PDF&res_license_id=CC-BY&sort=score+desc%2C+metadata_modified+desc-20",
        "https://data.e-gov.go.jp/data/dataset/?q=白書&res_format=PDF&res_license_id=cc-by&sort=score+desc%2C+metadata_modified+desc-20",
        "https://data.e-gov.go.jp/data/dataset/?q=白書&res_format=PDF&res_license_id=gjstu&sort=score+desc%2C+metadata_modified+desc-20",
        "https://data.e-gov.go.jp/data/dataset/?q=白書&res_format=PDF&res_license_id=CC-BY&sort=score+desc%2C+metadata_modified+desc-20",]

last_pages = [211, 40, 4, 108, 10, 9]
# ダウンロードするPDFファイルを保存するディレクトリのパス
download_dir = 'pdf_downloads'
if not os.path.exists(download_dir):
    os.makedirs(download_dir)

def crawl_pages(url, last_page=384):
    crawl_search_pdf(url)
    print("page1をクロールしました。")
    for next in range(2, last_page+1):
        next_url = url + "&page=" + str(next)
        crawl_search_pdf(next_url)
        print("page" + str(next) + "をクロールしました。")

def crawl_search_pdf(url):
    """指定されたURLからPDFリンクを見つける"""
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    li_tag = soup.find_all('li', class_='list_dataset_item')
    
    for target in li_tag:
        for link in target.find_all('a', string=['PDF', 'pdf'], href=True):
            href = link.get('href')
            crawl_all_pdfs("https://data.e-gov.go.jp"+href)
    
def crawl_all_pdfs(url):
    """指定されたURLからPDFリンクを見つけてダウンロードする"""
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    li_tag = soup.find_all('li', class_='list_dataset_item resource-item')

    # PDFリンクのリストをリスト内包表記で抽出
    pdf_links = [[link.get('href') for link in target.find_all('a') if link.get('href').endswith('.pdf')] for target in li_tag]
    filtered_pdf_links = [element for element in pdf_links if element]
    Parallel(n_jobs=-1, verbose=0)([delayed(write_pdf_links_to_file)(pdf_link[0]) for pdf_link in filtered_pdf_links])

def write_pdf_links_to_file(pdf_link):
    # PDFリンクをファイルに書き込む
    with open("pdf_downloads/urls.txt", "a", encoding="utf-8") as file:
        file.write(pdf_link + "\n")  # "\n" は新しい行を開始します

# クローリングを開始する
for url, last_page in zip(urls,last_pages):
    crawl_pages(url, last_page=last_page)
# Out:
# page1をクロールしました。
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 57
#      55 # クローリングを開始する
#      56 for url, last_page in zip(urls,last_pages):
# ---> 57     crawl_pages(url, last_page=last_page)
#
# Cell In[4], line 25, in crawl_pages(url, last_page)
#      23 for next in range(2, last_page+1):
#      24     next_url = url + "&page=" + str(next)
# ---> 25     crawl_search_pdf(next_url)
#      26     print("page" + str(next) + "をクロールしました。")
#
# Cell In[4], line 30, in crawl_search_pdf(url)
#      28 def crawl_search_pdf(url):
#      29     """指定されたURLからPDFリンクを見つける"""
# ---> 30     response = requests.get(url)
#      31     soup = BeautifulSoup(response.text, 'html.parser')
#      32     li_tag = soup.find_all('li', class_='list_dataset_item')
#
# File ~/miniconda3/envs/.venv/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/envs/.venv/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/.venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/.venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/.venv/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/envs/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~/miniconda3/envs/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/miniconda3/envs/.venv/lib/python3.11/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File ~/miniconda3/envs/.venv/lib/python3.11/http/client.py:1390, in HTTPConnection.getresponse(self)
#    1388 try:
#    1389     try:
# -> 1390         response.begin()
#    1391     except ConnectionError:
#    1392         self.close()
#
# File ~/miniconda3/envs/.venv/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File ~/miniconda3/envs/.venv/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File ~/miniconda3/envs/.venv/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/miniconda3/envs/.venv/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/.venv/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# !cd /home/ubuntu/ucllm_nedo_prod_kawagoshi/data_management

# %%
import requests
import PyPDF2
import re
import json
import os
from io import BytesIO

def extract_text_from_pdf_with_pypdf2(url):
    # PDFファイルをダウンロードする
    response = requests.get(url)
    response.raise_for_status()  # HTTPエラーをチェック
    texts = []
    json_text = {}
    # ダウンロードしたPDFファイルをメモリ上で開く
    with BytesIO(response.content) as f:
        # PyPDF2を使用してPDFファイルを読み込む
        pdf_reader = PyPDF2.PdfReader(f)
        text = ""
        
        # 各ページからテキストを抽出
        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]
            text += page.extract_text() if page.extract_text() else ''
        
    without_kaigyou_text = text.replace('\n', '')
    cleaned_text = re.sub(r'\.\.+', '', without_kaigyou_text)

    json_text['text'] = cleaned_text 
    texts.append(json_text)
    return texts

# 使用例
# download_dir = 'pdf_downloads'
# if not os.path.exists(download_dir):
#     os.makedirs(download_dir)
# url = "https://www.ppc.go.jp/files/pdf/nichibeiou_ekkyouiten_report.pdf"
# texts = extract_text_from_pdf_with_pypdf2(url)
# # JSONLファイルに保存
# with open('pdf_downloads/scraped_data.jsonl', 'a', encoding='utf-8') as file:
#     for data in texts:
#         json_line = json.dumps(data, ensure_ascii=False)  # JSON形式の文字列に変換
#         file.write(json_line + '\n')  
# print(texts[0])  

# urls.txtに保存されたURLからPDFをダウンロードしてテキストを抽出
with open('/home/ubuntu/ucllm_nedo_prod_kawagoshi/data_management/preprocessing/download_dataset/pdf_downloads/urls.txt', 'r', encoding='utf-8') as file:
    urls = file.readlines()
    for url in urls:
        try:
            texts = extract_text_from_pdf_with_pypdf2(url.replace('\n', ''))
            # JSONLファイルに保存
            with open('/home/ubuntu/ucllm_nedo_prod_kawagoshi/data_management/output/datasets/scraped_data.jsonl', 'a', encoding='utf-8') as file:
                for data in texts:
                    json_line = json.dumps(data, ensure_ascii=False)  # JSON形式の文字列に変換
                    file.write(json_line + '\n')
        except Exception as e:
            print(str(e.args) +  url)
            continue
# Out:
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_0802.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_0802.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_0806.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_0806.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_0903.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_0903.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_0811.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_0811.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_0902.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_0902.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_0905.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_0905.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_0908.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_0908.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_111027_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_111027_01.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_111027_02.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_111027_02.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_111027_03.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_111027_03.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_111027_04.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_111027_04.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_111027_05.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_111027_05.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_111027_06.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_111027_06.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_111027_07.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_111027_07.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_111027_08.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_111027_08.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_111121_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_111121_01.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_120209_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_120209_01.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_120601_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_120601_01.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_120807_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_120807_01.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_121114_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_121114_01.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_130208_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_130208_01.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_130514_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/tyoushu_kanjo_130514_01.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo0802.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo0802.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo0806.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo0806.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo0903.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo0903.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo0811.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo0811.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo0902.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo0902.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo0905.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo0905.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo0908.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo0908.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo111027_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo111027_01.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo111027_02.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo111027_02.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo111027_03.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo111027_03.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo111027_04.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo111027_04.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo111027_05.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo111027_05.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo111027_06.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo111027_06.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo111027_07.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo111027_07.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo111027_08.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo111027_08.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo111121_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo111121_01.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo120209_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo120209_01.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo120601_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo120601_01.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo120807_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo120807_01.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo121114_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo121114_01.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo130208_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo130208_01.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo130514_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/rousai_kanjo130514_01.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_h250509.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_h250509.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_h250208.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_h250208.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_h241109.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_h241109.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_h240809.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_h240809.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_h240423.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_h240423.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_h240201.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_h240201.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_h231111.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_h231111.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_h230803.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_h230803.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_h210511.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_h210511.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_0510.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_0510.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_1011.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_1011.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_1008.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_1008.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_1006.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_1006.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_1003.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_1003.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_0912.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_0912.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_0908.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_0908.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_0906.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_0906.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_0902.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_0902.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_0812.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_0812.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_0802.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_0802.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_0806.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_0806.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_0808.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/koyou_kanjo_0808.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_0802.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_0802.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_0806.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_0806.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_0808.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_0808.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_0811.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_0811.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_0902.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_0902.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_0906.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_0906.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_0908.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_0908.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_1002.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_1002.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_1006.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_1006.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_1009.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_1009.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_1011.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_1011.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_1102.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_1102.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_1106.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_1106.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_1109.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_1109.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_111217.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_111217.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_120319.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_120319.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_120720.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_120720.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_121019.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_121019.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_121221.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_121221.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_130308.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/ippan_kaikei_130308.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_100304.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_100304.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_100419.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_100419.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_100519.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_100519.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_100811.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_100811.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_101104.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_101104.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_110119.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_110119.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_110516.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_110516.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_120220_1.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_120220_1.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_120220_2.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_120220_2.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_120220_3.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_120220_3.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_120424_1.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_120424_1.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_120726_1.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_120726_1.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_121101_1.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_121101_1.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_130128_1.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_130128_1.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_130424_1.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_130424_1.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_130718_1.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_tokubetsu_130718_1.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_0802.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_0802.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_0809.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_0809.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_0812.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_0812.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_0130.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_0130.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_0130_2.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_0130_2.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_120130_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_120130_01.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_120130_02.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_120130_02.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_120130_03.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_120130_03.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_120130_04.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_120130_04.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_120127_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_120127_01.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_120628_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_120628_01.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_120828_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_120828_01.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_130404.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_130404.pdf
#
# ('404 Client Error: Not Found for url: https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_130731_01.pdf',)https://www.mhlw.go.jp/sinsei/chotatu/zuikeisinsa/dl/nenkin_jidou_130731_01.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/personal_pia_datamapping_report_2021.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/offshore_DPA_report_R4_03.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/ecsite_report.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/offshore_DPA_report_R3_12.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/dpo_report202103.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/personal_date_report2019_1.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/personal_date_cases2019.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/personal_date_cases_summary2019.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/300926_daisansyateikyou_report.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/201803_shogaikoku.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/201803_kojinshikibetsu_fugou.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/camera_houseido_chosa_R503.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/R4_chikotai_chosa.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/R4_chuushou_anzenkanri_summary.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/R4_chuushou_anzenkanri_analysisreport.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/R4_chuushou_anzenkanri_report.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/R5_optout_surveyresult.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/R503_pets_houseido_report.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/major_european_countries_camera_report_R403.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/nichibeiou_ekkyouiten_report.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/nichibeiou_ekkyouiten_kekka.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/gdpr-doukou-report.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/201803_shogaikoku.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/nichibeiou_ekkyouiten_report.pdf
#
# ('PyCryptodome is required for AES algorithm',)https://www.ppc.go.jp/files/pdf/nichibeiou_ekkyouiten_kekka.pdf

# %%
def download_pdf(link):
    """PDFファイルをダウンロードする関数"""
    response = requests.get(link)
    filename = link.split('/')[-1]
    with open(os.path.join(download_dir, filename), 'wb') as f:
        f.write(response.content)
    print(f"{filename} をダウンロードしました。")
